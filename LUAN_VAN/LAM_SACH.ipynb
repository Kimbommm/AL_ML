# %%
import pandas as pd

# Đường dẫn tới file CSV
file_path = r"C:\Users\admin\AL_ML\DU_LIEU\대전광역시_시내버스 기반정보_20230329.csv"

# Đọc file CSV với mã hóa EUC-KR
data = pd.read_csv(file_path, encoding='euc-kr')

# Hiển thị 5 dòng đầu tiên của dữ liệu
print(data.head())
# Out:
#     순번       국토부 코드      정산 코드 정류장 코드      정류장명      행정구역코드    시도명 시군구명 읍면동명  \
# 0  1.0  184005309.0  8002633.0  20010  중앙로역8번출구  3014010100  대전광역시   중구  은행동
# 1  2.0  183002193.0  8001995.0  12000     성남네거리  3011011400  대전광역시   동구  가양동
# 2  3.0  183002072.0  8001344.0  11200    새들뫼아파트  3011011000  대전광역시   동구   대동
# 3  4.0  183002143.0  8005855.0  12200    현암초등학교  3011011800  대전광역시   동구  삼성동
# 4  5.0  183002237.0  8005864.0  13200     안아감마을  3011012900  대전광역시   동구  신상동
#
#   유개승강장 버스안내단말기 설치유무       와이좌표        엑스좌표
# 0     O            O  36.329791  127.424634
# 1     O            O  36.341222  127.437233
# 2     O            O  36.328085  127.443068
# 3     O            O  36.342396  127.420014
# 4     O            X  36.353203  127.515947

# %%
# Đọc dữ liệu từ file CSV
data = pd.read_csv(r"C:\Users\admin\AL_ML\DU_LIEU\대전광역시_시내버스 기반정보_20230329.csv", encoding='euc-kr')

# Đổi tên cột
data.rename(columns={
    "순번": "stt",
    "국토부 코드": "ma_khoan",
    "정산 코드": "ma_cham_soc",
    "정류장 코드": "ma_diem_dung",
    "정류장명": "ten_diem_dung",
    "행정구역코드": "ma_hanh_chinh",
    "시도명": "ten_tinh",
    "시군구명": "ten_huyen",
    "읍면동명": "ten_xa",
    "유개승강장": "gan_dung",
    "버스안내단말기 설치유무": "thiet_bi_huong_dan",
    "와이좌표": "toa_do_y",
    "엑스좌표": "toa_do_x"
}, inplace=True)

# Hiển thị 5 dòng đầu tiên để kiểm tra
print(data.head())
# Out:
#    stt     ma_khoan  ma_cham_soc ma_diem_dung ten_diem_dung ma_hanh_chinh  \
# 0  1.0  184005309.0    8002633.0        20010      중앙로역8번출구    3014010100
# 1  2.0  183002193.0    8001995.0        12000         성남네거리    3011011400
# 2  3.0  183002072.0    8001344.0        11200        새들뫼아파트    3011011000
# 3  4.0  183002143.0    8005855.0        12200        현암초등학교    3011011800
# 4  5.0  183002237.0    8005864.0        13200         안아감마을    3011012900
#
#   ten_tinh ten_huyen ten_xa gan_dung thiet_bi_huong_dan   toa_do_y    toa_do_x
# 0    대전광역시        중구    은행동        O                  O  36.329791  127.424634
# 1    대전광역시        동구    가양동        O                  O  36.341222  127.437233
# 2    대전광역시        동구     대동        O                  O  36.328085  127.443068
# 3    대전광역시        동구    삼성동        O                  O  36.342396  127.420014
# 4    대전광역시        동구    신상동        O                  X  36.353203  127.515947

# %%
from tabulate import tabulate

# In DataFrame với tabulate
print(tabulate(data.head(), headers='keys', tablefmt='psql', showindex=False))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 from tabulate import tabulate
#       3 # In DataFrame với tabulate
#       4 print(tabulate(data.head(), headers='keys', tablefmt='psql', showindex=False))
#
# ModuleNotFoundError: No module named 'tabulate'

# %%
# Out:
# ['c:\\Users\\admin\\AppData\\Local\\Programs\\Python\\Python312\\python312.zip', 'c:\\Users\\admin\\AppData\\Local\\Programs\\Python\\Python312\\DLLs', 'c:\\Users\\admin\\AppData\\Local\\Programs\\Python\\Python312\\Lib', 'c:\\Users\\admin\\AppData\\Local\\Programs\\Python\\Python312', '', 'C:\\Users\\admin\\AppData\\Roaming\\Python\\Python312\\site-packages', 'C:\\Users\\admin\\AppData\\Roaming\\Python\\Python312\\site-packages\\win32', 'C:\\Users\\admin\\AppData\\Roaming\\Python\\Python312\\site-packages\\win32\\lib', 'C:\\Users\\admin\\AppData\\Roaming\\Python\\Python312\\site-packages\\Pythonwin', 'c:\\Users\\admin\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages']
